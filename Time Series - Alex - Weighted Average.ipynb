# %% [markdown]
# # Weighted Forecasting for Time Series Store forecast
# * By Alex Dance https://www.linkedin.com/in/alex-dance/
# * This notebook is one of several notebooks for a project to improve store and product forecasts
# 1.	EDA – Exploratory Data Analysis – includes working with annual forecasts
# 2.	Main Modelling
# 3.	XG Boost modelling by Month
# 4.	Weighted average
# 5.	ARIMA – Month and Other Modelling
# 6.	Deep Learning
#
# * This forecast does not use a model but rather weightings and average weightings multiplied by average sales to give a forecast

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error

# %%
class color:  # Testing to make the heading look a liitle more impressive
   BOLD = '\033[1m'

# %%
df = pd.read_csv(r'C:/Users/alexd/Alex Folder 1/Capstone - Store Forecast/train.csv')
df.head()
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
originaldf = pd.read_csv(r'C:/Users/alexd/Alex Folder 1/Capstone - Store Forecast/train.csv')

# %%
split = "2017-01-01"

# %%
df.head()
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
df['date'] =  pd.to_datetime(df['date'])

# %% [markdown]
# # Function for Error calculations

# %%
def calculate_errorb(test_sales,  test_prediction):
    MSE_test = mean_squared_error(y_true=test_sales,  y_pred=test_prediction) # Mean Square Error (MAE)
    MAE_test = mean_absolute_error(y_true=test_sales,  y_pred=test_prediction) # Mean Absolute Error (MAE)
    MAPE = np.mean(np.abs(test_prediction - test_sales  ) **2)  # Mean Absolute Percentage Error (MAPE)
    RMSE  = np.mean(np.sqrt((test_prediction - test_sales) ** 2))    
    return{'MSE_test': MSE_test ,'MAE_test': MAE_test,  'MAPE':MAPE, 'RMSE':RMSE}

# %% [markdown]
# # Feature Engineering

# %%
df.head()
# Out:
#         date  store  item  sales
# 0 2013-01-01      1     1     13
# 1 2013-01-02      1     1     11
# 2 2013-01-03      1     1     14
# 3 2013-01-04      1     1     13
# 4 2013-01-05      1     1     10

# %%
split = "2016-12-31"

# %%
df['ItemStoreCombined'] = df['item'].map(str) + '-' + df['store'].map(str)

# %%
df.head()
# Out:
#         date  store  item  sales ItemStoreCombined
# 0 2013-01-01      1     1     13               1-1
# 1 2013-01-02      1     1     11               1-1
# 2 2013-01-03      1     1     14               1-1
# 3 2013-01-04      1     1     13               1-1
# 4 2013-01-05      1     1     10               1-1

# %%
df['dayofweek'] = df['date'].dt.dayofweek
df['quarter'] = df['date'].dt.quarter
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year
df['dayofyear'] = df['date'].dt.dayofyear
df['dayofmonth'] = df['date'].dt.day
df['weekofyear'] = df['date'].dt.weekofyear

# %%
df = df.set_index('date')

# %% [raw]
# # Splitting and make Test Train

# %%
df.head()
# Out:
#             store  item  sales ItemStoreCombined  dayofweek  quarter  month  \
# date
# 2013-01-01      1     1     13               1-1          1        1      1
# 2013-01-02      1     1     11               1-1          2        1      1
# 2013-01-03      1     1     14               1-1          3        1      1
# 2013-01-04      1     1     13               1-1          4        1      1
# 2013-01-05      1     1     10               1-1          5        1      1
#
#             year  dayofyear  dayofmonth  weekofyear
# date
# 2013-01-01  2013          1           1           1
# 2013-01-02  2013          2           2           1
# 2013-01-03  2013          3           3           1
# 2013-01-04  2013          4           4           1
# 2013-01-05  2013          5           5           1

# %%
df_train = df[ :split ]

# %%
df_test = df[split : ]

# %%
df_train.head()
# Out:
#             store  item  sales ItemStoreCombined  dayofweek  quarter  month  \
# date
# 2013-01-01      1     1     13               1-1          1        1      1
# 2013-01-02      1     1     11               1-1          2        1      1
# 2013-01-03      1     1     14               1-1          3        1      1
# 2013-01-04      1     1     13               1-1          4        1      1
# 2013-01-05      1     1     10               1-1          5        1      1
#
#             year  dayofyear  dayofmonth  weekofyear
# date
# 2013-01-01  2013          1           1           1
# 2013-01-02  2013          2           2           1
# 2013-01-03  2013          3           3           1
# 2013-01-04  2013          4           4           1
# 2013-01-05  2013          5           5           1

# %%
df_test_final = df_test.copy()

# %%
df_test_final =df_test_final.drop (['dayofweek', 'quarter','month', 'year', 'dayofyear', 'weekofyear'],axis=1)

# %%
train_cols=list(df_train.columns)

# %%
print(train_cols)
# Out:
# ['store', 'item', 'sales', 'ItemStoreCombined', 'dayofweek', 'quarter', 'month', 'year', 'dayofyear', 'dayofmonth', 'weekofyear']

# %%
df_train = df_train.loc[:,train_cols] #XXXXXXX

# %% [markdown]
# # Same for Test

# %%
test_cols=list(df_test.columns)

# %%
df_test = df_test.loc[:,test_cols] #XXXXXXX

# %% [markdown]
# # Now Working on Training review

# %%
df_train['Calculated_year'] =  df_train.index.year - min(df_train.index.year) + 1

# %%
df_train.head()
# Out:
#             store  item  sales ItemStoreCombined  dayofweek  quarter  month  \
# date
# 2013-01-01      1     1     13               1-1          1        1      1
# 2013-01-02      1     1     11               1-1          2        1      1
# 2013-01-03      1     1     14               1-1          3        1      1
# 2013-01-04      1     1     13               1-1          4        1      1
# 2013-01-05      1     1     10               1-1          5        1      1
#
#             year  dayofyear  dayofmonth  weekofyear  Calculated_year
# date
# 2013-01-01  2013          1           1           1                1
# 2013-01-02  2013          2           2           1                1
# 2013-01-03  2013          3           3           1                1
# 2013-01-04  2013          4           4           1                1
# 2013-01-05  2013          5           5           1                1

# %%
df_train['Calculated_year'].value_counts()
# Out:
# 4    183000
# 3    182500
# 2    182500
# 1    182500
# Name: Calculated_year, dtype: int64

# %% [markdown]
# # Now working through the weightings
# * This is a solution that a lot of standard forecasts would be completed, often in excel
# * This solution is completed to see how it compares
# * In summary it shows how weightings of the month and then aply that weightings across a total forecast
# * Multiple different weightings can be applied
# * With such a high number of rows this would be impractical using Excel

# %%
month_weighting= (( df_train.groupby(['month']).agg([np.nanmean]).sales - np.nanmean(df_train.sales) ) / np.nanmean(df_train.sales)).rename(columns={'nanmean':'month_weighting'})
df_train=df_train.join(month_weighting,how='left',on='month')

# %%
df_train.tail()
# Out:
#             store  item  sales ItemStoreCombined  dayofweek  quarter  month  \
# date
# 2016-12-27     10    50     60             50-10          1        4     12
# 2016-12-28     10    50     43             50-10          2        4     12
# 2016-12-29     10    50     68             50-10          3        4     12
# 2016-12-30     10    50     63             50-10          4        4     12
# 2016-12-31     10    50     64             50-10          5        4     12
#
#             year  dayofyear  dayofmonth  weekofyear  Calculated_year  \
# date
# 2016-12-27  2016        362          27          52                4
# 2016-12-28  2016        363          28          52                4
# 2016-12-29  2016        364          29          52                4
# 2016-12-30  2016        365          30          52                4
# 2016-12-31  2016        366          31          52                4
#
#             month_weighting
# date
# 2016-12-27        -0.249279
# 2016-12-28        -0.249279
# 2016-12-29        -0.249279
# 2016-12-30        -0.249279
# 2016-12-31        -0.249279

# %%
month_weighting.head(13)
# Out:
#        month_weighting
# month
# 1            -0.319326
# 2            -0.246433
# 3            -0.093797
# 4             0.053017
# 5             0.135099
# 6             0.206043
# 7             0.281457
# 8             0.132709
# 9             0.052223
# 10           -0.019591
# 11            0.057928
# 12           -0.249279

# %%
year_weighting= (( df_train.groupby(['year']).agg([np.nanmean]).sales - np.nanmean(df_train.sales) ) /  np.nanmean(df_train.sales)).rename(columns={'nanmean':'year_weighting'})

# %%
print(year_weighting)
# Out:
#       year_weighting
# year
# 2013       -0.140220
# 2014       -0.010923
# 2015        0.032537
# 2016        0.118282

# %%
CAGR = 0.096 #only for using on the train data - can be adjusted

# %%
year_weighting.loc[6,:] =  np.mean(CAGR)*3
df_train=df_train.join(year_weighting,how='left',on='year')

# %%
weekday_weighting= ( ( df_train.groupby(['dayofweek']).agg([np.nanmean]).sales - np.nanmean(df_train.sales) ) /  np.nanmean(df_train.sales)).rename(columns={'nanmean':'weekday_weighting'})
df_train=df_train.join(weekday_weighting,how='left',on='dayofweek')

# %%
store_item_weighting= ( ( df_train.groupby(['store','item']).agg([np.nanmean]).sales - np.nanmean(df_train.sales) ) / np.nanmean(df_train.sales)).rename(columns={'nanmean':'store_item_weighting'})
df_train=df_train.join(store_item_weighting,how='left',on=['store','item'])

# %%
df_train['product_combined_weighting']=np.product(df_train.loc[:,['month_weighting','year_weighting','weekday_weighting','store_item_weighting',]]+1,axis=1)

# %%
df_train.sample()
# Out:
#             store  item  sales ItemStoreCombined  dayofweek  quarter  month  \
# date
# 2014-03-22      1    21     32              21-1          5        1      3
#
#             year  dayofyear  dayofmonth  weekofyear  Calculated_year  \
# date
# 2014-03-22  2014         81          22          12                2
#
#             month_weighting  year_weighting  weekday_weighting  \
# date
# 2014-03-22        -0.093797       -0.010923           0.122128
#
#             store_item_weighting  product_combined_weighting
# date
# 2014-03-22             -0.307967                    0.696025

# %%
df_train.tail()
# Out:
#             store  item  sales ItemStoreCombined  dayofweek  quarter  month  \
# date
# 2016-12-27     10    50     60             50-10          1        4     12
# 2016-12-28     10    50     43             50-10          2        4     12
# 2016-12-29     10    50     68             50-10          3        4     12
# 2016-12-30     10    50     63             50-10          4        4     12
# 2016-12-31     10    50     64             50-10          5        4     12
#
#             year  dayofyear  dayofmonth  weekofyear  Calculated_year  \
# date
# 2016-12-27  2016        362          27          52                4
# 2016-12-28  2016        363          28          52                4
# 2016-12-29  2016        364          29          52                4
# 2016-12-30  2016        365          30          52                4
# 2016-12-31  2016        366          31          52                4
#
#             month_weighting  year_weighting  weekday_weighting  \
# date
# 2016-12-27        -0.249279        0.118282          -0.076576
# 2016-12-28        -0.249279        0.118282          -0.074857
# 2016-12-29        -0.249279        0.118282          -0.011256
# 2016-12-30        -0.249279        0.118282           0.056470
# 2016-12-31        -0.249279        0.118282           0.122128
#
#             store_item_weighting  product_combined_weighting
# date
# 2016-12-27              0.419121                    1.100146
# 2016-12-28              0.419121                    1.102194
# 2016-12-29              0.419121                    1.177967
# 2016-12-30              0.419121                    1.258654
# 2016-12-31              0.419121                    1.336878

# %%
df_train.Calculated_year.nunique()
# Out:
# 4

# %%
df_train.Calculated_year.value_counts()
# Out:
# 4    183000
# 3    182500
# 2    182500
# 1    182500
# Name: Calculated_year, dtype: int64

# %%
print(weekday_weighting)
# Out:
#            weekday_weighting
# dayofweek
# 0                  -0.207027
# 1                  -0.076576
# 2                  -0.074857
# 3                  -0.011256
# 4                   0.056470
# 5                   0.122128
# 6                   0.191042

# %%
print(month_weighting)
# Out:
#        month_weighting
# month
# 1            -0.319326
# 2            -0.246433
# 3            -0.093797
# 4             0.053017
# 5             0.135099
# 6             0.206043
# 7             0.281457
# 8             0.132709
# 9             0.052223
# 10           -0.019591
# 11            0.057928
# 12           -0.249279

# %%
print(store_item_weighting)
# Out:
#             store_item_weighting
# store item
# 1     1                -0.616305
#       2                 0.017385
#       3                -0.364471
#       4                -0.616427
#       5                -0.682033
# ...                          ...
# 10    46                0.266392
#       47               -0.527397
#       48                0.106590
#       49               -0.365553
#       50                0.419121
#
# [500 rows x 1 columns]

# %%
df_train.head()
# Out:
#             store  item  sales ItemStoreCombined  dayofweek  quarter  month  \
# date
# 2013-01-01      1     1     13               1-1          1        1      1
# 2013-01-02      1     1     11               1-1          2        1      1
# 2013-01-03      1     1     14               1-1          3        1      1
# 2013-01-04      1     1     13               1-1          4        1      1
# 2013-01-05      1     1     10               1-1          5        1      1
#
#             year  dayofyear  dayofmonth  weekofyear  Calculated_year  \
# date
# 2013-01-01  2013          1           1           1                1
# 2013-01-02  2013          2           2           1                1
# 2013-01-03  2013          3           3           1                1
# 2013-01-04  2013          4           4           1                1
# 2013-01-05  2013          5           5           1                1
#
#             month_weighting  year_weighting  weekday_weighting  \
# date
# 2013-01-01        -0.319326        -0.14022          -0.076576
# 2013-01-02        -0.319326        -0.14022          -0.074857
# 2013-01-03        -0.319326        -0.14022          -0.011256
# 2013-01-04        -0.319326        -0.14022           0.056470
# 2013-01-05        -0.319326        -0.14022           0.122128
#
#             store_item_weighting  product_combined_weighting
# date
# 2013-01-01             -0.616305                    0.207355
# 2013-01-02             -0.616305                    0.207741
# 2013-01-03             -0.616305                    0.222022
# 2013-01-04             -0.616305                    0.237230
# 2013-01-05             -0.616305                    0.251974

# %%
df_train['sales_prediction']=np.round(df_train.product_combined_weighting*np.round(np.nanmean(df_train.sales),1))

# %%
average_train_sales = np.nanmean(df_train.sales)
print(average_train_sales)
# Out:
# 50.61022861054072

# %%
df_train.head()
# Out:
#             store  item  sales ItemStoreCombined  dayofweek  quarter  month  \
# date
# 2013-01-01      1     1     13               1-1          1        1      1
# 2013-01-02      1     1     11               1-1          2        1      1
# 2013-01-03      1     1     14               1-1          3        1      1
# 2013-01-04      1     1     13               1-1          4        1      1
# 2013-01-05      1     1     10               1-1          5        1      1
#
#             year  dayofyear  dayofmonth  weekofyear  Calculated_year  \
# date
# 2013-01-01  2013          1           1           1                1
# 2013-01-02  2013          2           2           1                1
# 2013-01-03  2013          3           3           1                1
# 2013-01-04  2013          4           4           1                1
# 2013-01-05  2013          5           5           1                1
#
#             month_weighting  year_weighting  weekday_weighting  \
# date
# 2013-01-01        -0.319326        -0.14022          -0.076576
# 2013-01-02        -0.319326        -0.14022          -0.074857
# 2013-01-03        -0.319326        -0.14022          -0.011256
# 2013-01-04        -0.319326        -0.14022           0.056470
# 2013-01-05        -0.319326        -0.14022           0.122128
#
#             store_item_weighting  product_combined_weighting  sales_prediction
# date
# 2013-01-01             -0.616305                    0.207355              10.0
# 2013-01-02             -0.616305                    0.207741              11.0
# 2013-01-03             -0.616305                    0.222022              11.0
# 2013-01-04             -0.616305                    0.237230              12.0
# 2013-01-05             -0.616305                    0.251974              13.0

# %% [markdown]
# # now apply the weightings to the test sales

# %%
df_test=df_test.join(month_weighting,how='left',on='month')

# %%
df_test['Calculated_year'] =  5

# %%
year_weighting_17 =0.22  # calculated seperately

# %%
df_test['year_weighting'] = year_weighting_17

# %%
df_test=df_test.join(weekday_weighting,how='left',on='dayofweek')

# %%
df_test=df_test.join(store_item_weighting,how='left',on=['store','item'])

# %%
df_test.head()
# Out:
#             store  item  sales ItemStoreCombined  dayofweek  quarter  month  \
# date
# 2016-12-31      1     1     14               1-1          5        4     12
# 2017-01-01      1     1     19               1-1          6        1      1
# 2017-01-02      1     1     15               1-1          0        1      1
# 2017-01-03      1     1     10               1-1          1        1      1
# 2017-01-04      1     1     16               1-1          2        1      1
#
#             year  dayofyear  dayofmonth  weekofyear  month_weighting  \
# date
# 2016-12-31  2016        366          31          52        -0.249279
# 2017-01-01  2017          1           1          52        -0.319326
# 2017-01-02  2017          2           2           1        -0.319326
# 2017-01-03  2017          3           3           1        -0.319326
# 2017-01-04  2017          4           4           1        -0.319326
#
#             Calculated_year  year_weighting  weekday_weighting  \
# date
# 2016-12-31                5            0.22           0.122128
# 2017-01-01                5            0.22           0.191042
# 2017-01-02                5            0.22          -0.207027
# 2017-01-03                5            0.22          -0.076576
# 2017-01-04                5            0.22          -0.074857
#
#             store_item_weighting
# date
# 2016-12-31             -0.616305
# 2017-01-01             -0.616305
# 2017-01-02             -0.616305
# 2017-01-03             -0.616305
# 2017-01-04             -0.616305

# %%
df_test['smry_product']=np.product(df_test.loc[:,['month_weighting','year_weighting','weekday_weighting','store_item_weighting',]]+1,axis=1)

# %%
df_test['weighted_sales_prediction']=df_test.smry_product*average_train_sales

# %%
average_train_sales
# Out:
# 50.61022861054072

# %%
df_test.sum()
# Out:
# store                                                                  1006500
# item                                                                   4666500
# sales                                                                 10757532
# ItemStoreCombined            1-11-11-11-11-11-11-11-11-11-11-11-11-11-11-11...
# dayofweek                                                               551500
# quarter                                                                 460000
# month                                                                  1197000
# year                                                                 369110500
# dayofyear                                                             33580500
# dayofmonth                                                             2884500
# weekofyear                                                             4875000
# month_weighting                                                       -93.8354
# Calculated_year                                                         915000
# year_weighting                                                           40260
# weekday_weighting                                                      154.597
# store_item_weighting                                                -2.035e-10
# smry_product                                                            223274
# weighted_sales_prediction                                             1.13e+07
# dtype: object

# %%
df_test.head()
# Out:
#             store  item  sales ItemStoreCombined  dayofweek  quarter  month  \
# date
# 2016-12-31      1     1     14               1-1          5        4     12
# 2017-01-01      1     1     19               1-1          6        1      1
# 2017-01-02      1     1     15               1-1          0        1      1
# 2017-01-03      1     1     10               1-1          1        1      1
# 2017-01-04      1     1     16               1-1          2        1      1
#
#             year  dayofyear  dayofmonth  weekofyear  month_weighting  \
# date
# 2016-12-31  2016        366          31          52        -0.249279
# 2017-01-01  2017          1           1          52        -0.319326
# 2017-01-02  2017          2           2           1        -0.319326
# 2017-01-03  2017          3           3           1        -0.319326
# 2017-01-04  2017          4           4           1        -0.319326
#
#             Calculated_year  year_weighting  weekday_weighting  \
# date
# 2016-12-31                5            0.22           0.122128
# 2017-01-01                5            0.22           0.191042
# 2017-01-02                5            0.22          -0.207027
# 2017-01-03                5            0.22          -0.076576
# 2017-01-04                5            0.22          -0.074857
#
#             store_item_weighting  smry_product  weighted_sales_prediction
# date
# 2016-12-31             -0.616305      0.394336                  19.957456
# 2017-01-01             -0.616305      0.379501                  19.206616
# 2017-01-02             -0.616305      0.252664                  12.787394
# 2017-01-03             -0.616305      0.294230                  14.891030
# 2017-01-04             -0.616305      0.294777                  14.918743

# %%
RMSE_weighted  = np.mean(np.sqrt((df_test['weighted_sales_prediction'] - df_test['sales']) ** 2)) 
print(RMSE_weighted)
# Out:
# 6.462572198330651
